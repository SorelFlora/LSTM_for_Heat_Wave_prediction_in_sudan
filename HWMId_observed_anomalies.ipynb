# %%
cd "/content/drive/MyDrive/HWMId_for prediction"
# Out:
# /content/drive/MyDrive/HWMId_for prediction

# %%
ls
# Out:
#  Ad-Damazin_HWMId.csv   Khartoum_HWMId.csv   Ouadi_Halfa_HWMId.csv
#  Al_Qadarif_HWMId.csv   Kosti_HWMId.csv      Singa_HWMId.csv
#  El_ObeidHWMId.csv      Nyala_HWMId.csv     'Variation of HWMId with respect to years.png'
#  Kassala_HWMId.csv      Omdurman_HWMId.csv

# %%
df = pd.read_csv('Ad-Damazin_HWMId.csv')
df
# Out:
#       time      lat      lon       HWMId
# 0   1940.0  11.7891  34.3592    0.000000
# 1   1941.0  11.7891  34.3592    0.968804
# 2   1942.0  11.7891  34.3592   17.627157
# 3   1943.0  11.7891  34.3592    0.000000
# 4   1944.0  11.7891  34.3592    0.000000
# ..     ...      ...      ...         ...
# 78  2018.0  11.7891  34.3592  104.202225
# 79  2019.0  11.7891  34.3592  123.888440
# 80  2020.0  11.7891  34.3592  104.965870
# 81  2021.0  11.7891  34.3592  170.130840
# 82  2022.0  11.7891  34.3592  125.267640
#
# [83 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import pandas as pd

def plot_multiple_time_series(file_paths, title='HWMId observed Anomaly with respect to years', xlabel='Years', ylabel='Anomaly'):

    plt.figure(figsize=(15, 8))

    for i, file_path in enumerate(file_paths):
        # Read the dataset
        df = pd.read_csv(file_path+'.csv')

        # Convert year to datetime by setting to the first day of the year
        df['time'] = pd.to_datetime(df['time'].astype(int), format='%Y')


        mean = df['HWMId'][23 : 52].mean()
        df['anomaly'] = df['HWMId'] - mean
        # Set date column as index
        #df.set_index('time', inplace=True)

        # Plot the time series data
        plt.plot(df['time'][0 : 82],df['anomaly'][0 : 82], linestyle ='-', label=f'{file_path}')

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid(True)
    plt.savefig('anomaly.png')
    plt.show()

# %%
name = ['Ad-Damazin_HWMId', 'Kassala_HWMId', 'Nyala_HWMId', 'Singa_HWMId', 'Al_Qadarif_HWMId',
        'Khartoum_HWMId', 'Omdurman_HWMId','El_ObeidHWMId', 'Kosti_HWMId', 'Ouadi_Halfa_HWMId']
# Plot the datasets
plot_multiple_time_series(name)
